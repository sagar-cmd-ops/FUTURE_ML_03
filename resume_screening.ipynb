# %%
# !pip install pandas scikit-learn nltk

# %%
import pandas as pd

data = {
    "resume": [
        "Python machine learning data analysis pandas numpy",
        "Java spring boot backend developer microservices",
        "Python deep learning tensorflow keras NLP",
        "SQL data analyst excel power bi tableau"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                               resume
# 0  Python machine learning data analysis pandas n...
# 1   Java spring boot backend developer microservices
# 2          Python deep learning tensorflow keras NLP
# 3            SQL data analyst excel power bi tableau

# %%
job_description = "Python machine learning deep learning data science"

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text

df['clean_resume'] = df['resume'].apply(clean_text)
job_clean = clean_text(job_description)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

all_text = df['clean_resume'].tolist() + [job_clean]

tfidf_matrix = vectorizer.fit_transform(all_text)

# %%
from sklearn.metrics.pairwise import cosine_similarity

resume_vectors = tfidf_matrix[:-1]
job_vector = tfidf_matrix[-1]

scores = cosine_similarity(resume_vectors, job_vector)

# %%
df['score'] = scores

df = df.sort_values(by='score', ascending=False)

df
# Out:
#                                               resume  \
# 0  Python machine learning data analysis pandas n...
# 2          Python deep learning tensorflow keras NLP
# 3            SQL data analyst excel power bi tableau
# 1   Java spring boot backend developer microservices
#
#                                         clean_resume     score
# 0  python machine learning data analysis pandas n...  0.489514
# 2          python deep learning tensorflow keras nlp  0.418963
# 3            sql data analyst excel power bi tableau  0.079044
# 1   java spring boot backend developer microservices  0.000000

# %%
def skill_gap(resume, job):

    resume_words = set(resume.split())
    job_words = set(job.split())

    missing = job_words - resume_words

    return ", ".join(missing)

df['missing_skills'] = df['clean_resume'].apply(lambda x: skill_gap(x, job_clean))
df['score'] = (df['score'] * 100).round(2)
df
# Out:
#                                               resume  \
# 0  Python machine learning data analysis pandas n...
# 2          Python deep learning tensorflow keras NLP
# 3            SQL data analyst excel power bi tableau
# 1   Java spring boot backend developer microservices
#
#                                         clean_resume  score  \
# 0  python machine learning data analysis pandas n...  48.95
# 2          python deep learning tensorflow keras nlp  41.90
# 3            sql data analyst excel power bi tableau   7.90
# 1   java spring boot backend developer microservices   0.00
#
#                                    missing_skills
# 0                                   science, deep
# 2                          science, data, machine
# 3        science, learning, python, deep, machine
# 1  science, learning, python, data, deep, machine
